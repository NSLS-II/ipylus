# %%
from databroker import DataBroker as db, get_table, get_fields, get_events, get_images
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# Command performed in Bluesky:
#
# In [7]: RE(bp.count([rixscam], num=5), reason='camera testing')

# %%
hdr = db[3852] # with x-rays
hdr = db[5684] # without x-rays
hdr = db[5685] # without x-rays

# %%
scan=hdr.start['scan_id']
scan
# Out:
# 5685

# %%
hdr.descriptors[0].data_keys.keys()
# Out:
# dict_keys(['rixscam_image'])

# %%
evs = db.get_events(hdr, fill=True)

# %%
events = list(evs)

# %%
events[0].data
# Out:
# {'rixscam_image': <Frames>
#  Length: 1 frames
#  Frame Shape: 1612 x 6604
#  Pixel Datatype: uint16}

# %%
events = list(db.get_events(hdr, fill=True))

# %%
e = events[0]

# %%
e.data
# Out:
# {'rixscam_image': <Frames>
#  Length: 1 frames
#  Frame Shape: 1612 x 6604
#  Pixel Datatype: uint16}

# %%
ims = db.get_images(headers=[hdr],name='rixscam_image')
#db.get_images(headers=[hdr],name='rixscam_hdf5_file_name')

# %%
ims[0][0]
# Out:
# Frame([[  0,   0,   0, ...,   0,   0,   0],
#        [  0, 195, 167, ..., 152, 167,   0],
#        [  0, 184, 184, ..., 148, 173,   0],
#        ...,
#        [  0, 190, 175, ..., 152, 170,   0],
#        [  0, 186, 164, ..., 144, 161,   0],
#        [  0,   0,   0, ...,   0,   0,   0]], dtype=uint16)

# %%
plt.imshow(ims[0][4])
# Out:
# <img src="data:image/png;base64,..." width="639.9166603096658">

# %%
db.fs.config
# Out:
# {'database': 'filestore-production-v1', 'host': 'xf02id1-ca1', 'port': 27017}
